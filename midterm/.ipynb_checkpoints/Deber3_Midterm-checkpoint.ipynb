# %% [markdown]
# ## Corrección de Midterm
# ### Sebastián Mena [212779]

# %% [markdown]
# ## Verdadero o falso con argumentos

# %% [markdown]
# ### 1.  Una función recursiva resuelve un problema resolviendo una parte mas pequeña del mismo problema

# %% [markdown]
# Verdadero, las funciones recursivas se llaman a sí mismas pero con una parte más pequeña por resolver. En algún momento, las partes serán tan pequeñas que se resuelven muy fácil y solo se 'sale' de todas las llamadas de la función con una respuesta a todo el problema.

# %% [markdown]
# ### 2.  Los modelos computacionales nos ayudan a analizar la complejidad de los algoritmos, ya que nos proveen de las especificaciones de la computadora en la cual estos se ejecutarían idealmente

# %% [markdown]
# Verdadero, los modelos computacionales nos dan especificaciones exactas de cierto tipo de computadora y con esas especificaciones podemos estudiar la complejidad y tiempo y memoria de los algoritmos que nos interesan. Se vieron dos tipos de modelos computacionales, RAM Y Pointer Machine.

# %% [markdown]
# ### 3.  La búsqueda en un árbol binario de búsqueda es siempre mas rápida que la búsqueda lineal en un arreglo

# %% [markdown]
# Falso, la búsqueda en un árbol binario puede llegar a ser igual de lenta que la búsqueda lineal de un arreglo con una complejidad O(n). Esta complejidad se da cuando se tiene un BST muy desbalanceado y que parece una lista en vez de un árbol binario.

# %% [markdown]
# ### 4. Un algoritmo de complejidad O(nlog(n)) es mas rápido que un algoritmo de complejidad O(n)

# %% [markdown]
# Falso. La notación Big Oh muestra el peor de los casos posibles en complejidad y en el peor de los casos, la función de nlog(n) crece mucho más rápido que la función lineal (n).

# %% [markdown]
# ### 5.  Un algoritmo de complejidad Ω(nlog(n)) es mas rápido que un algoritmo de complejidad Ω(n)

# %% [markdown]
# Falso. La notación Big Omega muestra el mejor de los casos posibles en complejidad y en este caso nlog(n) crece más rápido que la función lineal (n). Pasando el n=10 la función nlog(n) siempre será más lenta que la función lineal normal de (n)

# %% [markdown]
# ## Problemas de programación
# #### Todo el código debe ser en Python. Si se requiere escribir funciones que hagan búsqueda o ordenamiento (search, sort), programe las funciones usando los conceptos aprendidos en clase. No use las funciones que Python provee para hacer esto.

# %% [markdown]
# ### 6. Dada una lista enlazada que represente un número. Por ejemplo, 123 es representado por la lista 1->2->3 si la lista es simple o con doble enlace si es doble. Escriba un programa que haga lo siguiente:
#
# 1. Reciba dos números A y B como input
#
# 2. Transforme estos números a listas enlazadas como la definida arriba
#
# 3. Implemente la resta de los números descritos por esas listas enlazadas. El resultado (A-B) debe ser almacenado en una lista enlazada.
#
# 4. Imprima el resultado concatenando el valor de los nodos de la lista enlazada resultante
#
# Nota: asuma que el número A es mayor que B

# %%
class Node:
    def __init__(self, val=None):
        self.val = val
        self.next_node = None
        self.prev_node = None

    def set_next_node(self, next_node):
        self.next_node = next_node




class DoublyLinkedList:
    def __init__(self, head_node=None):
        self.head_node = head_node

    def insert_start(self, new_node):
        if self.head_node is None:
            self.head_node = new_node
            return

        self.head_node.prev_node = new_node
        new_node.next_node = self.head_node
        self.head_node = new_node

    def insert_end(self, new_node):
        if self.head_node is None:
            self.head_node = new_node
            return

        node = self.head_node
        if node:
            node = node.next_node
        else:
            return

        new_node.prev_node = node
        node.next_node = new_node
        return new_node

    def insert_after_node(self, new_node, searched_node):
        if self.head_node is None:
            self.head_node = new_node
            return
        n = self.head_node
        while n:
            if n == searched_node:
                break
            n = n.next_node
        if not n:
            raise ValueError("nodo no encontrado")
        # SE NECESITAN 4 ACTUALIZACIONES DE PUNTEROS PARA PODER INSERTAR EN MEDIO DE LA LISTA#
        new_node.next_node = searched_node.next_node
        searched_node.next_node = new_node
        new_node.prev_node = searched_node

        return new_node

    def insert_before_node(self, new_node, searched_node):
        if self.head_node is None:
            self.head_node = new_node
            return

        n = self.head_node
        while n:
            if n == searched_node:
                break
            n = n.next_node
        if not n:
            raise ValueError("nodo no encontrado")

        new_node.prev_node = searched_node.prev_node
        searched_node.prev_node = new_node
        new_node.next_node = searched_node
        new_node.prev_node.next_node = new_node

        return new_node

    def list_traverse(self):
        node = self.head_node
        while node:
            print(node.val)
            node = node.next_node

    def length(self):
        n = 0
        node = self.head_node
        while node:
            node = node.next_node
            n += 1
        return n


numero1 = input('Inserta el primer número: ')
numero2 = input('Inserta el segundo número: ')


listaN1 = DoublyLinkedList()
listaN2_mock = DoublyLinkedList()
listaN2 = DoublyLinkedList()
listaResta = DoublyLinkedList()

for digit in numero1:
    nodo = Node(digit)
    listaN1.insert_start(nodo)

for digit in numero2:
    nodo = Node(digit)
    listaN2_mock.insert_start(nodo)

longitud = listaN1.length()

if listaN1.length() > listaN2.length():
    nodo = Node(0)
    listaN2.insert_start(nodo)
    for digit in numero2:
        nodo = Node(digit)
        listaN2.insert_start(nodo)
else:
    for digit in numero2:
        nodo = Node(digit)
        listaN2.insert_start(nodo)

nodoL1 = listaN1.head_node
nodoL2 = listaN2.head_node
deuda = 0

for n in range(longitud):
    digitoN1 = int(nodoL1.val)
    digitoN2 = int(nodoL2.val)
    digitoN2 = digitoN2+deuda
    deuda = 0
    if digitoN2 > digitoN1:
        digitoN1 = digitoN1+10
        deuda = 1
    digitoResta = digitoN1 - digitoN2
    nodoL1 = nodoL1.next_node
    nodoL2 = nodoL2.next_node
    nodo = Node(digitoResta)
    listaResta.insert_start(nodo)


listaResta.list_traverse()
# Out:
# Inserta el primer número: 123
# Inserta el segundo número: 45
# 0
# 7
# 8

# %% [markdown]
# ### 7.  Cuando introducimos el concepto de pilas (stacks), usamos como ejemplos una pila de platos. Siguiendo con el ejemplo, una pila de platos con muchos platos se puede caer. Para evitar esto, se puede empezar una nueva pila.
#
# Implemente una clase de Python que defina un arreglo de stacks. La idea de tener este arreglo es que cuando un stack alcance su capacidad máxima, un nuevo stack empieza en el mismo arreglo. Las operación pop() debe retornar el mismo valor que lo haría si estuviéramos usando un stack simple.
#
# Nota: Debe definir los elementos de la clase: el arreglo de stacks, la capacidad del arreglo (# de stacks en el arreglo), la capacidad de cada stack (# de elementos que puede tener el stack).
#
# Hint: Cuando ingrese elementos (push), los elementos van al stack que este activo (el stack que recibe y retira elementos). Debe manejar las condiciones para cambiar el stack activo (cuando un push() deja al stack sin elementos, o cuando un pop() llena el stack).

# %%
import ctypes

# Hay que diferenciar los métodos de Stack() de los de ArrayOfStacks()
class ArrayOfStacks(object):
    def __init__(self, num):
        self.total_item_count: int = 0
        self.num: int = num
        self.stacks_in_arrays = self._create_array_of_stacks(self.num)
        self.active_index: int = 0

    def _create_array_of_stacks(self, num):
        return [Stack(num)] * num

    def probarArrays(self):
        for i in range(0, self.num):
            if self.stacks_in_arrays[i]:
                print("Me encuentro en el stack número " + str(i))
                print("Número de elementos en el stack actual es de: " + str(self.stacks_in_arrays[i].item_count))
                print("Número de stacks usados actualmente es de: " + str(self.total_item_count))


    def push_in_array(self, item):
        # Chequeo de capacidad total
        if self.total_item_count is self.num:
            raise ValueError("No hay más capacidad")

        print("ANTES DE INGRESAR UN ELEMENTO, ESTOY EN EL STACK NÚMERO:   " + str(self.active_index))
        print("EL NÚMERO DE ELEMENTOS EN EL ARRAY ACTUAL ES DE: " + str(self.stacks_in_arrays[self.active_index].item_count) + "\n")
        if self.stacks_in_arrays[self.active_index].item_count is self.num:
            self.active_index += 1
            self.stacks_in_arrays[self.active_index].item_count = 0
            print("ACABO DE SUBIR UNA UNIDAD EL INDEX ACTIVO, AHORA ES:  " + str(self.active_index))

        # Chequeo de capacidad local del stack dentro del array
        if self.stacks_in_arrays[self.active_index].item_count is not self.num:
            self.stacks_in_arrays[self.active_index].push(item)
            if self.stacks_in_arrays[self.active_index].item_count == 0:
                self.total_item_count += 1

    def pop_in_array(self):
        respaldo = self.stacks_in_arrays[self.total_item_count - 1].pop()
        if self.stacks_in_arrays[self.total_item_count - 1].item_count == 0:
            self.total_item_count -= 1
        return respaldo


class Stack(object):
    def __init__(self, n):
        self.item_count = 0
        self.n = n
        self.stack = self._create_stack(self.n)

    def _create_stack(self, n):
        return (n * ctypes.py_object)()

    def push(self, item):
        if self.item_count == self.n:
            raise ValueError("no more capacity")
        self.stack[self.item_count] = item
        self.item_count += 1

    def pop(self):
        c = self.stack[self.item_count - 1]
        self.stack[self.item_count-1] = ctypes.py_object
        self.item_count -= 1
        return c

    def top(self):
        return self.stack[self.item_count - 1]

    def full(self):
        if self.item_count == self.n:
            return True
        return False

    def empty(self):
        if self.item_count == 0:
            return True
        return False

    def size(self):
        return self.item_count


pruebaArrayOfStacks = ArrayOfStacks(5)
#pruebaArrayOfStacks.probarArrays()
pruebaArrayOfStacks.push_in_array(1)
pruebaArrayOfStacks.push_in_array(2)
pruebaArrayOfStacks.push_in_array(3)
pruebaArrayOfStacks.push_in_array(4)
pruebaArrayOfStacks.push_in_array(5)
pruebaArrayOfStacks.push_in_array(6)
pruebaArrayOfStacks.push_in_array(7)
pruebaArrayOfStacks.push_in_array(8)
pruebaArrayOfStacks.push_in_array(9)
pruebaArrayOfStacks.push_in_array(10)
pruebaArrayOfStacks.push_in_array(11)
pruebaArrayOfStacks.push_in_array(12)
pruebaArrayOfStacks.push_in_array(13)
pruebaArrayOfStacks.push_in_array(14)
print(pruebaArrayOfStacks.pop_in_array())
print(pruebaArrayOfStacks.pop_in_array())
print(pruebaArrayOfStacks.pop_in_array())
print(pruebaArrayOfStacks.pop_in_array())
print(pruebaArrayOfStacks.pop_in_array())
# Out:
# ANTES DE INGRESAR UN ELEMENTO, ESTOY EN EL STACK NÚMERO:   0
# EL NÚMERO DE ELEMENTOS EN EL ARRAY ACTUAL ES DE: 0
#
# ANTES DE INGRESAR UN ELEMENTO, ESTOY EN EL STACK NÚMERO:   0
# EL NÚMERO DE ELEMENTOS EN EL ARRAY ACTUAL ES DE: 1
#
# ANTES DE INGRESAR UN ELEMENTO, ESTOY EN EL STACK NÚMERO:   0
# EL NÚMERO DE ELEMENTOS EN EL ARRAY ACTUAL ES DE: 2
#
# ANTES DE INGRESAR UN ELEMENTO, ESTOY EN EL STACK NÚMERO:   0
# EL NÚMERO DE ELEMENTOS EN EL ARRAY ACTUAL ES DE: 3
#
# ANTES DE INGRESAR UN ELEMENTO, ESTOY EN EL STACK NÚMERO:   0
# EL NÚMERO DE ELEMENTOS EN EL ARRAY ACTUAL ES DE: 4
#
# ANTES DE INGRESAR UN ELEMENTO, ESTOY EN EL STACK NÚMERO:   0
# EL NÚMERO DE ELEMENTOS EN EL ARRAY ACTUAL ES DE: 5
#
# ACABO DE SUBIR UNA UNIDAD EL INDEX ACTIVO, AHORA ES:  1
# ANTES DE INGRESAR UN ELEMENTO, ESTOY EN EL STACK NÚMERO:   1
# EL NÚMERO DE ELEMENTOS EN EL ARRAY ACTUAL ES DE: 1
#
# ANTES DE INGRESAR UN ELEMENTO, ESTOY EN EL STACK NÚMERO:   1
# EL NÚMERO DE ELEMENTOS EN EL ARRAY ACTUAL ES DE: 2
# ...

# %% [markdown]
# ### 8. Dada una cola con prioridad (PriorityQueue) que contiene elementos (k,v) donde k define la prioridad y v define el valor. Recuerde que los valores con menor k tienen mayor prioridad, es decir si tenemos dos elementos (k1, v1) y (k2, v2), v2 tiene preferencia para salir de la cola antes que v1 si k2< k1. Definimos algunas de las operaciones como siguen:
#
# ```
# import ctypes
#
# class PriorityQueue(object):
#
# """
#
# Implementation of the queue data structure
#
# """
#
# def __init__(self, n):
#
# self.item_count = 0
#
# self.n = n
#
# self.queue = self._create_queue(self.n)
#
# def _create_queue(self, n):
#
# """
#
# Creates a new stack of capacity n
#
# """
#
# return (n * ctypes.py_object)()
#
# def dequeue(self):
#
# """
#
# Remove an element from the queue
#
# """
#
# c = self.queue[0]
#
# for i in range(1,self.item_count):
#
# self.queue[i-1] = self.queue[i]
#
# self.queue[self.item_count - 1] = ctypes.py_object
#
# self.item_count -= 1
#
# return c
# ```
#
# ### Implemente los métodos enqueue y decreaseKey, tal que ambos métodos tengan complejidad O(log(n)), sin utilizar funciones nativas de Python. Por ejemplo, si necesita hacer una búsqueda, no use la función de Python que implementa esto, programe la función usando for o while loops.

# %%
# Priority Queue
# Sebastián Mena

import ctypes


class PriorityQueue(object):

    def __init__(self, n):
        self.item_count = 0
        self.n = n
        self.queue = self._create_queue(self.n)

    def _create_queue(self, n):
        return (n * ctypes.py_object)()

    def enqueue(self, item):
        if self.item_count == self.n:
            raise ValueError("No más capacidad")

        self.queue[self.item_count] = item
        self.item_count += 1

        quick_sort(0, self.item_count-1, self.queue)


    def dequeue(self):
        c = self.queue[0]
        for i in range(1, self.item_count):
            self.queue[i - 1] = self.queue[i]
        self.queue[self.item_count - 1] = ctypes.py_object
        self.item_count -= 1
        return c

    def first(self):
        return self.queue[0]

    def full(self):
        if self.item_count == self.n:
            return True
        else:
            return False

    def empty(self):
        if self.item_count == 0:
            return True
        return False

    def size(self):
        return self.item_count

    def decreaseKey(self, item):
        for i in range(self.item_count):
            if self.queue[i] == item:
                buscado = self.queue[i]
                if buscado[0] == 0:
                    print("No se puede priorizar más")
                    return
                key = buscado[0] - 1
                valor = buscado[1]
                itemNuevo = (key, valor)
                self.queue[i] = itemNuevo
                return

def partir(inicio, final, array):
    pivote_original = inicio
    pivote = array[inicio]

    while inicio < final:
        while inicio < len(array) and array[inicio] <= pivote:
            inicio += 1

        while array[final] > pivote:
            final -= 1

        if inicio < final:
            array[inicio], array[final] = array[final], array[inicio]

    array[final], array[pivote_original] = array[pivote_original], array[final]

    return final


def quick_sort(inicio, final, array):
    if inicio < final:
        particion = partir(inicio, final, array)

        quick_sort(inicio, particion - 1, array)
        quick_sort(particion + 1, final, array)


# ELEMENTO 'V' CON UNA PRIORIDAD(KEY) 'K'#

queuePrueba = PriorityQueue(6)
queuePrueba.enqueue((1, 2))
queuePrueba.enqueue((2, 4))
queuePrueba.enqueue((0, 1))
queuePrueba.enqueue((9, 43))
queuePrueba.enqueue((1, 3))
queuePrueba.enqueue((4, 5))

queuePrueba.dequeue()
queuePrueba.dequeue()

queuePrueba.enqueue((0, 1))

queuePrueba.decreaseKey((9, 43))
print(".....................")

for i in range(queuePrueba.item_count):
    print(queuePrueba.queue[i])

print(sorted(queuePrueba.queue[0:queuePrueba.item_count]))
# Out:
# .....................
# (0, 1)
# (1, 3)
# (2, 4)
# (4, 5)
# (8, 43)
# [(0, 1), (1, 3), (2, 4), (4, 5), (8, 43)]

# %% [markdown]
# ### 9. Tenemos un árbol binario (binary tree), definimos a un nodo X como rojo, si todos los nodos en el recorrido de la raiz al nodo X tienen un valor que es menor o igual a X. Por ejemplo, en el ejemplo de abajo:
#
# ![](./binary_tree.png)
#
# El recorrido hacia el nodo 3 de la izquierda es 3 → 1 → 3, como todos los valores en este recorrido son menores o iguales a 3 (3=3 y 1<3), el nodo es rojo. Similarmente, en el sub-árbol de la derecha, los nodos 4 y 5 también son rojos. Escriba una función en Python que cuente el numero total de nodos rojos. El input de esta función es la raíz del árbol binario.

# %%
## BINARY TREE PARA EL EJERCICIO DE MIDTERM
##

class TreeNode:
    def __init__(self, val=0, left=None, right=None):
        self.val = val
        self.left = left
        self.right = right


## PRE ORDER TRAVERSAL
# Implementation using stacks
def preorderTraversal(root):
    if root is None:
        return []
    stack = [root]
    out = []

    while stack:
        node = stack.pop()
        if node:
            out.append(node.val)
            for child in [node.right, node.left]:
                if child:
                    stack.append(child)
    return out


# Implementation using recursion
def preorderTraversalrec(root):
    if root is None:
        return []

    # ESTO ES LO ÚNICO QUE SE HACE, CONSIGUE ESE VALOR Y DESPUÉS SOLO SE HACE LA RECURSIÓN
    out = [root.val]

    out += preorderTraversalrec(root.left)
    out += preorderTraversalrec(root.right)

    return out


## IN ORDER TRAVERSAL

# Implementation using stacks
def inorderTraversal(root):
    if root is None:
        return []

    node = root
    stack = []
    out = []

    while node or stack:
        while node:
            stack.append(node)
            node = node.left
        node = stack.pop()
        out.append(node.val)
        node = node.right
    return out


# Implementation using recursion
def inorderTraversalrec(root):
    if root is None:
        return []

    # RECURSIVO
    out = inorderTraversalrec(root.left)

    # ESTA LÍNEA ES LO ÚNICO QUE HACE ESTE ALGORITMO APARTE DE LA RECURSION
    out += [root.val]

    # RECURSIVO
    out += inorderTraversalrec(root.right)

    return out


# EJERCICIO ARBOL ROJOS

previous = []
counter = 0

def countRedNodes(root):
    if root is None:
        return

    global counter
    previous.append(root.val)

    # Recursivo izquierda
    countRedNodes(root.left)

    # Codigo efectivo
    for element in previous:
        if element > root.val:
            counter -= 1
            break
    counter += 1

    # Recursivo derecha
    countRedNodes(root.right)

    if root.left is None and root.right is None:
        previous.pop()

    return counter


i = TreeNode(5)
h = TreeNode(1, right=i)

d = TreeNode(3)
b = TreeNode(1, left=d, right=h)

c = TreeNode(6)

j = TreeNode(1)

g = TreeNode(5, right=c)
f = TreeNode(1, right=j)
e = TreeNode(4, left=f, right=g)

a = TreeNode(2, left=b, right=e)

print("Preorder")
print(preorderTraversal(a))
print("Inorder")
print(inorderTraversal(a))
print("TOTAL DE ROJOS: " + str(countRedNodes(a)))
# Out:
# Preorder
# [2, 1, 3, 1, 5, 4, 1, 1, 5, 6]
# Inorder
# [3, 1, 1, 5, 2, 1, 1, 4, 5, 6]
# TOTAL DE ROJOS: 6
